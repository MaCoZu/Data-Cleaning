# %%
import pandas as pd

# %%
# data = pd.read_stata('../data/World_Values_Survey/Trends_VS_1981_2022_stata_v4_0.dta', convert_categoricals=False)
data[:2]
# Out:
#    studyno             version                        doi  stdyno_w  \
# 0     4001  4-0-0 (2024-06-30)  doi.org/10.14281/18241.27       341
# 1     4001  4-0-0 (2024-06-30)  doi.org/10.14281/18241.27       341
#
#            versn_w  S001  s002  S002VS  S003 COUNTRY_ALPHA  ...  Y022B Y022C  \
# 0  WVS3 v.20180912     2     3       3     8           ALB  ...   0.66   1.0
# 1  WVS3 v.20180912     2     3       3     8           ALB  ...   0.00   1.0
#
#        Y023     Y023A     Y023B     Y023C   Y024 Y024A  Y024B  Y024C
# 0  0.296296  0.000000  0.444444  0.444444  0.165  0.33    0.0  0.165
# 1  0.333333  0.111111  0.444444  0.444444  0.165  0.33    0.0  0.165
#
# [2 rows x 732 columns]

# %%
data.to_csv('wvs.csv')

# %%
path = '../data/World_Values_Survey/wvs_labels.CSV'

# %%
with open(path, 'rb') as f:
  text = f.read()

# %%
text
# Out:
# b'ID ,"Common Dictionary: Variable name\n\n[Orange cells= variables included in JOINT EVS/WVS\n","Common Dictionary: Variable label\n"\r\n1,studyno,Study number\r\n2,version,Version\r\n3,doi,Digital Object Identifier \r\n4,stdyno_w,Study number (wave)\r\n5,studyno,Study number\r\n6,S001,Study\r\n7,S002,Wave\r\n8,S002evs,EVS-wave\r\n9,s002vs,Chronology of EVS-WVS waves\r\n10,S003,Country (ISO 3166-1 Numeric code)\r\n11,COW_ALPHA,CoW country code alpha\r\n12,COW_NUM,Country (CoW Numeric code)\r\n13,S004,Set\r\n14,S006,Original respondent number\r\n15,S007,Unified respondent number\r\n16,S007_01,Unified respondent number (EVS/WVS)\r\n17,S008,Interviewer number\r\n18,S009,Country (ISO 3166-1 Alpha-2 code)\r\n19,mode,Mode of data collection\r\n20,S010,Total length of interview\r\n21,S011A,Time of the interview - Start [hh.mm]\r\n22,S011B,Time of the interview - End [hh.mm]\r\n23,S012,Date interview [YYYYMMDD]\r\n24,S013,Respondent interested during the interview\r\n25,S013B,Interview privacy\r\n26,S016,Language of the interview (WVS/EVS list of languages)\r\n27,S016a,Language of the interview (ISO 639-1 alpha-2 / 639-2 alpha-3) \r\n28,S017,Weight\r\n29,S018,Equilibrated weight-1000\r\n30,S019,Equilibrated weight-1500\r\n31,pwght,Population size weight\r\n32,S020,Year survey\r\n33,S021,Country - wave - study - set - year\r\n34,S022,Year/month of start-fieldwork\r\n35,S023,Year/month of end-fieldwork\r\n36,S024,Country - wave\r\n37,S025,Country - year\r\n38,S036,Flag variable: Duplicate Cases\r\n39,mm_fw_end_fu_EVS5,Year/month of end-fieldwork (matrix design) (EVS5)\r\n40,mm_fw_start_fu_EVS5,Year/month of start-fieldwork (matrix design) (EVS5)\r\n41,mm_matrix_group_EVS5,Matrix attribution (group/variable bloc) (EVS5)\r\n42,mm_mixed_mode_EVS5,Mixed mode/matrix design (EVS5)\r\n43,mm_mode_fu_EVS5,Mode of data collection (follow-up) (EVS5)\r\n44,mm_v277_fu_EVS5,Date of interview (follow-up) (EVS5)\r\n45,mm_v278a_fu_r_EVS5,Time of the interview -Start (constructed) (follow-up) (EVS5)\r\n46,mm_v279a_fu_r_EVS5,Time of the interview -End (constructed) (follow-up) (EVS5)\r\n47,mm_year_fu_EVS5,Survey year (follow-up) (EVS5)\r\n48,A001,Important in life: Family\r\n49,A002,Important in life: Friends\r\n50,A003,Important in life: Leisure time\r\n51,A004,Important in life: Politics\r\n52,A005,Important in life: Work\r\n53,A006,Important in life: Religion\r\n54,A007,Important in life: Service to others\r\n55,A008,Feeling of happiness\r\n56,A009,State of health (subjective)\r\n57,A010,Ever felt very excited or interested\r\n58,A011,Ever felt restless\r\n59,A012,Ever felt proud because someone complimented you\r\n60,A013,Ever felt very lonely or remote from other people\r\n61,A014,Ever felt pleased about having accomplished something\r\n62,A015,Ever felt bored\r\n63,A016,Ever felt on top of the world\r\n64,A017,Ever felt depressed or very unhappy\r\n65,A018,Ever felt that things were going your way\r\n66,A019,Ever felt upset because somebody criticized you\r\n72,A025,Respect and love for parents\r\n73,A026,Parents responsibilities to their children\r\n75,A027,Important child qualities: Good manners\r\n77,A029,Important child qualities: independence\r\n78,A030,Important child qualities: Hard work\r\n80,A032,Important child qualities: feeling of responsibility\r\n82,A034,Important child qualities: imagination\r\n83,A035,Important child qualities: tolerance and respect for other people\r\n86,A038,Important child qualities: thrift saving money and things\r\n87,A039,Important child qualities: determination perseverance\r\n88,A040,Important child qualities: religious faith\r\n89,A041,Important child qualities: unselfishness\r\n90,A042,Important child qualities: obedience\r\n92,A043_01,Important child qualities: None\r\n100,A046,Abortion when the mothers health is at risk\r\n101,A047,Abortion when child physically handicapped\r\n102,A048,Abortion when woman not married\r\n103,A049,Abortion if not wanting more children\r\n116,A058,Spend time with friends\r\ ...

# %%
labels = pd.read_csv('../data/World_Values_Survey/wvs_labels.CSV', encoding='unicode_escape')
labels
# Out:
#       ID   \
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# ...   ...
# 1775  NaN
# 1776  NaN
# 1777  NaN
# 1778  NaN
# 1779  NaN
#
#      Common Dictionary: Variable name\n\n[Orange cells= variables included in JOINT EVS/WVS\n  \
# 0                                               studyno
# 1                                               version
# 2                                                   doi
# 3                                              stdyno_w
# 4                                               studyno
# ...                                                 ...
# 1775                                                NaN
# 1776                                                NaN
# 1777                                                NaN
# 1778                                                NaN
# 1779                                                NaN
#
#      Common Dictionary: Variable label\n
# 0                           Study number
# 1                                Version
# 2             Digital Object Identifier
# 3                    Study number (wave)
# 4                           Study number
# ...                                  ...
# 1775                                 NaN
# 1776                                 NaN
# 1777                                 NaN
# 1778                                 NaN
# 1779                                 NaN
#
# [1780 rows x 3 columns]
